# %% [markdown]
# 1 初始化git
# git config --global user.name "John Doe"
# git config --global user.email johndoe@example.com
#
# 2 设置全局代理
# git config --global http.proxy http://127.0.0.1:7890
# git config --global https.proxy http://127.0.0.1:7890
#
# 3 查询git日志
# git log(按q退出)
#
# 4 先在github创建项目，再用Remote——add Remote，可以远程上传
#
# 5 分类：工作区、暂存区、本地仓库
#
# 6 回退版本：get reset
# git res
#
# 7 初始化：git init
# 第一次提交：
# git add .
# git commit -m "initial commit for QMIX version"
# 排除result：
# echo "results/" >> .gitignore
# echo "__pycache__/" >> .gitignore
# echo "*.pt" >> .gitignore
# echo "src/3rdparty/" >> .gitignore
#
# 8 配置vscode默认终端为Anaconda
# setting.json
#
# 9 克隆github的代码
# git clone https://github.com/CindyMoon616/Algorithms-Learning.git
#
# 10 具体操作流程
# 装箱：git add .
# 封箱并贴单：git commit -m "message"
# 发货：git push origin main
# 取件：git pull origin main
#
# 11 LeetCode Hot200：https://algo.itcharge.cn/00_preface/00_08_interview_200_list/#%E6%8E%92%E5%BA%8F%E7%AE%97%E6%B3%95%E9%A2%98%E7%9B%AE
#
# 12 对于Markdown语言，路径都是相对当前文件的
