# %%
from typing import Optional
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    # 83 删除排序链表中的重复元素
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head or not head.next:
            return head
        left=head
        right=head
        while right:
            right=right.next
            while right and left.val == right.val:
                right=right.next
            left.next=right
            left=left.next
        return head
    def deleteDuplicates_1(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
        cur=head
        while cur.next:
            if cur.val == cur.next.val:
                cur.next=cur.next.next
            else:
                cur=cur.next
        return head
    
    # 82 删除排序链表中的重复元素2
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        dummy_head=ListNode(-101)
        dummy_head.next=head
        cur=dummy_head
        flag=0
        while cur.next:
            while cur.next.next and cur.next.val == cur.next.next.val:
                cur.next=cur.next.next
                flag=1
            if flag==1: # 去掉重复的
                cur.next=cur.next.next
                flag=2 # 不许更新cur
            if flag==0: # 干干净净的
                cur=cur.next
            flag=0

        return dummy_head.next
    
    def deleteDuplicates_2(self, head: Optional[ListNode]) -> Optional[ListNode]:
        dummy_head=ListNode(-1)
        dummy_head.next=head
        
        cur=dummy_head
        while cur.next and cur.next.next:
            if cur.next.val ==cur.next.next.val:
                temp=cur.next
                while temp and temp.next and temp.val == temp.next.val:
                    temp=temp.next
                cur.next=temp.next
            else:
                cur=cur.next
        return dummy_head.next
    
    # 206 反转链表
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
        
        cur=head
        lis=[]
        while cur:
            lis.append(cur.val)
            cur=cur.next
        dummy_head=ListNode(0)
        curr=dummy_head
        for num in reversed(lis):
            cur_node=ListNode(num)
            curr.next=cur_node
            curr=curr.next
        return dummy_head.next
    def reverseList_iter(self, head: Optional[ListNode]) -> Optional[ListNode]:
        pre=None
        cur=head
        while cur:
            next=cur.next
            cur.next=pre
            pre=cur
            cur=next
        return pre
    def reverseList_rec(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head or not head.next:
            return head
        new_head=self.reverseList(head.next)
        head.next.next=head
        head.next=None
        return new_head
        
    # 92 反转链表2
    def reverseBetween(self, head: Optional[ListNode], left: int, right: int) -> Optional[ListNode]:
        if not head or not head.next:
            return head
        if left==1:
            pre=None
            cur=head
            left_node=head
            for _ in range(right):
                next=cur.next
                cur.next=pre
                pre=cur
                cur=next
            left_node.next=cur
            return pre
        if left >= 2:
            left2_node=head
            for _ in range(left-2):
                left2_node=left2_node.next
            pre=None
            left_node=left2_node.next
            cur=left2_node.next
            for _ in range(right-left+1):
                next=cur.next
                cur.next=pre
                pre=cur
                cur=next
            left2_node.next=pre
            left_node.next=cur
            return head
    # 25 K个一组翻转链表
    def reverseKGroup(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        begin,end=[],[]
        cur=head
        if not head or not head.next or k==1:
            return head
        while cur:
            begin.append(cur)
            begin_node=cur
            count=1
            while cur and count<k:
                cur=cur.next
                count+=1
            if count==k and cur is not None:
                end.append(cur)
                pre=None
                cur=begin_node
                for _ in range(k):
                    next=cur.next
                    cur.next=pre
                    pre=cur
                    cur=next
            
            else: # 不成比例的结束（end比begin少一个）
                n=len(end)
                if n==0:
                    return begin[0]
                elif n==1:
                    begin_node1=begin[0]
                    begin_node2=begin[1]
                    begin_node1.next=begin_node2
                    return end[0]
                else:
                    for i in range(n-1):
                        begin_node=begin[i]
                        end_node=end[i+1]
                        begin_node.next=end_node
                    begin_node1=begin[-2]
                    begin_node2=begin[-1]
                    begin_node1.next=begin_node2
                    return end[0]
        # 成比例结束
        n=len(end)
        if n==1:
            return end[0]
        for i in range(n-1):
            begin_node=begin[i]
            end_node=end[i+1]
            begin_node.next=end_node
        return end[0]
                
s=Solution()
s.reverseKGroup([1,2,3,4,5],2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20732\266739028.py in <module>
#     179
#     180 s=Solution()
# --> 181 s.reverseKGroup([1,2,3,4,5],2)
#     182
#     183
#
# ~\AppData\Local\Temp\ipykernel_20732\266739028.py in reverseKGroup(self, head, k)
#     131         begin,end=[],[]
#     132         cur=head
# --> 133         if not head or not head.next:
#     134             return head
#     135         while cur:
#
# AttributeError: 'list' object has no attribute 'next'

# %%
lis=[1,3,4,2,4]
for i in range(0):
    print(1)
